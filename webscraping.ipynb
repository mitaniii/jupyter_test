# %% [markdown]
# # Webスクレイピング

# %% [markdown]
# ## ライブラリのインストール
# - requests
# - beautifulsoup4
# ```
# pip install requests beautifulsoup4
# ```

# %%
# Wikipediaの「今日は何の日」を取得する
import requests
from bs4 import BeautifulSoup

url = "https://ja.wikipedia.org/"
response = requests.get(url)

soup = BeautifulSoup(response.content, "html.parser")
today = soup.find("div", attrs={"id": "on_this_day"}).text
print(today)
# Out:
# 今日は何の日 2月3日
#
# 節分
# ミラノ勅令発布。ローマ帝国がキリスト教を公認（313年）
# バルトロメウ・ディアスがアフリカ大陸南端に到達（1488年）
# チューリップ・バブル崩壊（1637年）
# 福澤諭吉死去（1901年、雪池忌）
# 通化事件（1946年）
# ソビエト連邦の無人宇宙探査機「ルナ9号」が史上初めて月面軟着陸に成功（1966年）
# 札幌オリンピック開幕（1972年）
# Netscapeブラウザのソースコードの公開方法の会議の中で、初めてオープンソースという言葉が使われる（1998年）

# %%
# today_list = []
# index = 1

today = soup.find("div", attrs={"id": "on_this_day"})
entries = today.find_all("li")
# for entry in entries:
#     today_list.append([index, entry.get_text()])
#     index += 1

# print(today_list)
#コメントアウトの部分でも同じ結果が得られる

for i, entry in enumerate(entries):
    print("%d: %s" % (i+1, entries[i].get_text())) #フォーマットも変えられる
# Out:
# 1: 節分
# 2: ミラノ勅令発布。ローマ帝国がキリスト教を公認（313年）
# 3: バルトロメウ・ディアスがアフリカ大陸南端に到達（1488年）
# 4: チューリップ・バブル崩壊（1637年）
# 5: 福澤諭吉死去（1901年、雪池忌）
# 6: 通化事件（1946年）
# 7: ソビエト連邦の無人宇宙探査機「ルナ9号」が史上初めて月面軟着陸に成功（1966年）
# 8: 札幌オリンピック開幕（1972年）
# 9: Netscapeブラウザのソースコードの公開方法の会議の中で、初めてオープンソースという言葉が使われる（1998年）

# %% [markdown]
# ### csvファイルに出力

# %%
import csv

today_list = []
for i, entry in enumerate(entries):
    today_list.append([i+1, entry.get_text()])

with open("output.csv", "w", encoding="shift_JIS") as f:
    writer = csv.writer(f, lineterminator="\n")
    writer.writerows(today_list)

# %%
# 正規表現を使う
import re

today_list = []
for i, entry in enumerate(entries):
    today_text = entry.get_text()
    today_text = today_text.replace("（","(").replace("）",")")
    match = re.search("\(([1-9].*?)年", today_text)
    if match:
        today_list.append([i+1, today_text, match.group(1)])
    else:
        today_list.append([i+1, today_text, ""])

with open("output2.csv", "w", encoding="shift_JIS") as f:
    writer = csv.writer(f, lineterminator="\n")
    writer.writerows(today_list)

# %% [markdown]
# ### はてなブックマーク

# %%
import requests
from bs4 import BeautifulSoup

url = "https://b.hatena.ne.jp/"
response = requests.get(url)
soup = BeautifulSoup(response.content, "html.parser")

top_entry = soup.find("section", attrs={"class": "entrylist-unit"})
entries = top_entry.find_all("h3", attrs={"class": "entrylist-contents-title"})

for entry in entries:
    print(entry.find("a").get_text("title"))
# Out:
# Twitterで凍結祭りが開催中と騒ぎに。外部サービスと連携しているアカウントが永久凍結に？（篠原修司） - 個人 - Yahoo!ニュース
# しげる on Twitter: "「回転寿司屋で醤油舐めたりして一体何が面白いのか」と昨日ワイフに聞かれたので、そこまでハードな悪事を働いておらず（←ここが重要）頭の緩い田舎のヤンキーは、身の回りのあらゆる物事にチキンレース性を見出して実行し、それを自慢することで仲間内で「伝説」を作る生き物なのだと説明した"
# 授業で日本語の「いる」と「ある」の違いを説明したら学生がうっとりした
# 眼鏡の曇り止めの使い方間違えてた
# 近親婚に対する反論が同性婚反対派のそれと区別つかないのマジウケるな。 ..
# マスクCEO、Twitterの無料API終了は「悪質なbotの排除」と説明　有料APIは月100ドル程度に
# 「俺の仕事が信用できないんですか？」工場でダブルチェックを嫌がる若い子を納得させた『チェックする理由』の言い方が素敵
# 卒業式や入学式でのマスク着用 推奨しないことを検討 政府 | NHK
# 岸田首相、教えて？「なぜ防衛費をあげるのですか」　世田谷の小学6年生たちが質問の手紙：東京新聞 TOKYO Web

# %%
top_entry = soup.find("section", attrs={"class": "entrylist-unit"})
entries = top_entry.find_all("div", attrs={"class": "entrylist-contents"})

for entry in entries:
    title_tag = entry.find("h3", attrs={"class": "entrylist-contents-title"})
    title = title_tag.find("a").get("title")
    print(title)

    users_tag = entry.find("span", attrs={"class": "entrylist-contents-users"})
    users = users_tag.get_text().strip()
    print(users)
# Out:
# Twitterで凍結祭りが開催中と騒ぎに。外部サービスと連携しているアカウントが永久凍結に？（篠原修司） - 個人 - Yahoo!ニュース
# 484 users
# しげる on Twitter: "「回転寿司屋で醤油舐めたりして一体何が面白いのか」と昨日ワイフに聞かれたので、そこまでハードな悪事を働いておらず（←ここが重要）頭の緩い田舎のヤンキーは、身の回りのあらゆる物事にチキンレース性を見出して実行し、それを自慢することで仲間内で「伝説」を作る生き物なのだと説明した"
# 414 users
# 授業で日本語の「いる」と「ある」の違いを説明したら学生がうっとりした
# 360 users
# 眼鏡の曇り止めの使い方間違えてた
# 371 users
# 近親婚に対する反論が同性婚反対派のそれと区別つかないのマジウケるな。 ..
# 329 users
# マスクCEO、Twitterの無料API終了は「悪質なbotの排除」と説明　有料APIは月100ドル程度に
# 227 users
# 「俺の仕事が信用できないんですか？」工場でダブルチェックを嫌がる若い子を納得させた『チェックする理由』の言い方が素敵
# 224 users
# 卒業式や入学式でのマスク着用 推奨しないことを検討 政府 | NHK
# 328 users
# 岸田首相、教えて？「なぜ防衛費をあげるのですか」　世田谷の小学6年生たちが質問の手紙：東京新聞 TOKYO Web
# 280 users

# %%
url = "https://b.hatena.ne.jp"
response = requests.get(url)
soup = BeautifulSoup(response.content, "html.parser")
top_entry = soup.find("section", attrs={"class": "entrylist-unit"})
entries = top_entry.find_all("div", attrs={"class": "entrylist-contents"})

for entry in entries:
    title_tag = entry.find("h3", attrs={"class": "entrylist-contents-title"})
    title = title_tag.find("a").get("title")
    print(title)

    bookmark_tag = entry.find("span", attrs={"class": "entrylist-contents-users"})
    bookmark_link = bookmark_tag.find("a").get("href")
    bookmark_url = url + bookmark_link

    response = requests.get(bookmark_url)
    soup = BeautifulSoup(response.content, "html.parser")
    comments = soup.find_all("span", attrs={"class": "entry-comment-text"})
    for comment in comments:
        print(comment.get_text())
# Out:
# Twitterで凍結祭りが開催中と騒ぎに。外部サービスと連携しているアカウントが永久凍結に？（篠原修司） - 個人 - Yahoo!ニュース
# 明らかに今がTwitterの競合サービスを打ち出す最大のチャンスなので、戦国時代のように世界中で我こそはと名乗りを上げているはず。乗り越えるサービスが出てきてほしい。
# なんやかんやこれは分水嶺な気がするなぁ。凍結されたら再度垢作ったり、異議申し立てて解除を待つ魅力はTwitterにはもう無い。
# 注意喚起(?)で電話番号の登録しときな！って見たけど、Twitterが原因なのにTwitterに個人情報を…！？！？？と思って何もしてない。
# はてブ連携で凍結されてる。記録ログ用に鍵垢ではてブ連携しか投稿してない垢が凍結された。通常の連携以外の投稿してないのが良くなかった可能性もあるが、投稿してても変わらなかったろうな／携帯番号は未登録垢
# 自動投稿されるサービスの利用で凍結、まさかー、と思ったけど、マシュマロ公式が凍結されているのは説得力ある。自衛にいくつか解除しておこうか……本当にTwitterさんどうなってるの……？
# サービスをどれくらいの速さで自壊させられるかの実験を見ているような気分になってきたな
# 今まで何度かこう云うのはあったが、どんなに不満があってもやはりツイッターじゃないとダメだって人が多くて結局は支持されてきたし、それを見透かした上での施策なんじゃないかなあ。
# Twitterの先週の発表「凍結基準を、緩和します」https://news.livedoor.com/lite/article_detail/23620571/
# 「常に最悪のケースを想定しろ。奴は必ずその少し斜め上を行く！」が一晩明けて早くも発動か。はてブの連携も対象なんかなー。連携以外の普通のツイートは減ったので、連携できないならいよいよ自分は辞められそう。
# Twitter連携めんどすぎて最近はGoogleの方にしてるが、ゲームのスクショ転送方法がいよいよメールかusbになってきた
# ただでさえ少ない俺の貴重なフォロワーが１０人くらい消えていた…
# “筆者は『マシュマロ』のほかに、『IFTTT』による自動投稿サービスを利用していました。まだ凍結されていない人は、いまのうちにこれらのサービスとの連携を一時停止した方が良いかもしれません”
# Twitterを頼りに生きている我が国の一部の層にとっては悲惨な事態。改めて考えると健全なSNSじゃないもんね。
# 正直これで盛り上がってるのでお手軽なキャンペーンになってると思う。呟かなくなってたアカウントが呟いたり、フォロワーが減ったなんだでワイワイしてる
# イーロンの大暴走だから理由なんて無いもんだけど、エロ絵ってサムネだけでわかるイラストをセンシティブフィルターせずこのご時世に外国製のSNSに出しといて何もしてないのに凍結された！って言ってて面白かった
# 今日もオワッターですね
# まじこわ。TWログイン系凍結されたら色々終わるな…。
# イーロンマスク以前のツイッターも運営の不透明さから色々言われてたし思うところもあったけど、あれは全然マシだったんだなあ…
# メチャメチャ度の上がり方が凄い。
# あめぞうから2chへの大移動のような流れなのでチャンス到来ですよ
# 現状で凍結したりしなかったりするのって、タイミングで、自動投稿系のサービスからTwitterにアクセスする→自動投稿系がTwitterの変更した(？)ルールに抵触している→凍結ってことなのかな？素人考えだけど
# マシュマロ使ってる人が軒並みヤラれてる気がする
# 実際にツイアカ凍結されたけど連携先のアカウントはそのままログインできてる。次のトークン更新までかな？ メ複垢ダメらしいし解凍までデトックス予定（永眠
# わたしもあれこれ連携させてるし自動投稿もさせてるけど凍結されてないな。凍結されたら…どうしようかなー。
# 凍結の多くはツイッター側にログインを求める承認の流入方向のサービス系統なのでは。
# 盗んだバイクで走り出すのがカッコいい時代もあったし、SNSがあったらヤバかった大人はいっぱいいるだろう
# 田舎に限らずヤンキー社会はそういうもんでは。やべーことでマウンティング合戦。
# つまるところYouTuberじゃん
# まあつまり、成人式での暴動と同じなのだよな。喉元過ぎればその施米コミュニティでの武勇伝になってしまいそうなところも。
# 暴走族や成人式のヤンキーを見て、行動の結果を推測できる知能があると思うてか？本当に中身が小学生低学年と同じくらい。どれだけ高いとこから飛び降りられるかの競争で骨折したバカヤンキーがいたなぁ…
# ホントこういうの数限りなくあったと思うし行為そのものは大したことないが、誰もが動画を撮りそしてすぐ発信できるところが一昔前とは違うんだよなぁ。ネットにアップされた時点でその個人的行為が公共性を持つ。
# はてなでも言い切ったり大げさに感情的に言うといっぱい星もらったりするからこういうのと地続きだよねぇ
# そういやこの前スピード違反だかで炎上してたレーサーはどうなったんだろうか？
# 授業で日本語の「いる」と「ある」の違いを説明したら学生がうっとりした
# 魂の有無が分かれ目になってるけど、魂は「ある」なんだよね。車輪がなければ車じゃないけど、車輪は車じゃない。
# 今、私は会社にある
# たしかに、パンダのぬいぐるみがソファにいたり、店の棚にあったりするよな。
# 「すみません。魂ありますか？」「そこになければないですね～」
# うちのルンバは「いる」
# 古語から「あり」は存在する、「おり」は居る・座っているなので魂の有無が意味するところかというと違うような。「ある」は生きてる人に使ってもいいんやで。「駿河の国にその人ありと謳われる清水次郎長」みたいに
# 日本語に限らない定期/言語学習ってただ慣れて覚えろみたいなの(動詞の不規則変化、名詞の性、英語の文字と発音の乖離etc.)が多い分、理屈でわかるものに遭遇すると嬉しいのはあるよな
# あー、なるほど。 “有生性（ゆうせいせい、英語：Animacy）とは、一種の文法カテゴリーで、名詞・代名詞などの指示対象のもつ生物としての性質をいう”
# 心はある、精神もある。背後に何かいる。メイドロボはいる？ある？
# 「する」と「なる」についても解説すると、さらに日本語の理解が深まるよ。
# うっとりしたという状態の意味がわからない
# 日本語話者は対象物の意思の有無を常に意識している。ある、いる以外に、持ってくると、連れてくるも同じで、英語、中国語ではどちらも同じ動詞になる。『帯』と『bring』
# 生きてればいる、死体になるとある、になる。魂っていうか反応がある存在だと居る、反応がない存在だとある、じゃないか？
# これさ、「あの人には娘が二人ある」とか「〜な人もある」ってまだ使う人が生きてるような用法まるっと無視してんだけど知識レベル大丈夫？　って思っちゃう。
# うっとりしたのは多分授業が眠かったから
# いる、だと意識をもったものがそこにいる感じがする。別に本当に意識を持ってなくても自分がそう感じたら、いる、って言っちゃう。魂か。
# ことばのきまりやん
# 聴講したのは保育園児か？
# 「日本スゲー」ポルノ。英語では農場にいる豚をpigと呼び、冷蔵庫ではporkとなる。別にうっとりしない。
# wikipedia読む限り魂という言葉と有生性が正しく対とは言えない気はする。この説明だと意志を持って行動する=魂ありという前提が必要では。人に教える立場、まして言語学なら言葉の仔細にもう少し配慮がいると思う。
# リビングデッド
# 「ホームに電車がいる」は成立しても「ホームに電車がある」は成立しない。電車自体に魂を感じているわけではないので、もう少し突っ込んだ説明をしないといけない気がするな。
# これおかしくもなんともなくていじめとかDVとか虐待されて育った子なんかはダブルチェックを自分をシメるなじるためにやると思う認知の歪みがあるからね…。正しく教育的見地からの発言でしょ。
# ×：俺の仕事が信用できない ○：誰であろうと信用すべきでない / 可用性、冗長性は「単体では必ずいつか失敗する」を前提にしているので、そういう認識を持つべき。
# 厳しいコメントも多いけど、新人教育の一環としてはアリなんじゃないかな。経験を重ねるうちに「粗探しをしてくれたおかげで助かった！」と思うときが来るのだろう
# 警戒心バリバリの不安が強い状態の人には、これありだと思う。チェック＝怒られるだし。成功体験を積み重ねて信用を得た方がいい。責任分散はいずれ教えたら。
# 子供騙しだし、それは若者だってわかってる。それでも言われ方で気分が良くなるってことはあるし、こりゃ素晴らしい対応。
# 本当のところは「俺がチェックしたらそのあと見つかったミスは俺の責任、チェック通してなかったらミスはお前の責任」かな…なので私は「俺を信用するな、お前がチェックしろ」って言う（笑）
# 世の中はケチつけたい人が大半だろうな。「いいね」って言ってあげたい人が増える世界になることをを祈りたい。
# 普通に「そうだよ」って言えばいいんじゃねえの…仕事の成果の担保を取る事を子供騙しみたいな理屈で納得させる方が不誠実だろうよ
# 似たような話では、自分が作ったものを持って行って新人にチェックさせるというのもあるよな。
# #ダブルチェック #現場猫 #仕事猫 「ベテランでもミスは起きるので~信頼するが信用せず~チェックを嫌がる若い子~俺の仕事が信用できないんですか？~『流石やな！』~言うためのチェックや~言い方一つでこうも違うのか」
# 本質的ではあるけどな。100のうち1の失敗を見つけることは99の成功を見つけることの裏返しだから。裏返して表現すればいい。
# SPOFは作らない方がええぞ。
# 馬鹿相手なら嘘ついてもいいって事ですか？？？？(違う
# なるほど
# むしろチェックしてミスがそのまま通過した場合チェックした管理職が責任取りますよね？と思いながら仕事してる（責任は取ってくれない）
# いい回答だなぁ〜　／
# 責任を分散させるための行為だと思っている
# きっと製薬とかには向かない人材ですね…。
# リフレーミングの良い例だ。ミスはいずれ発生するだろうから、その時ダブルチェックの大事さに気付くだろう
# チェックする側とされる側の信頼関係の構築になるね。信頼できない人のジャッジって嫌だし、警戒するもの。だから教師と子供なんかも初めはたくさん褒めて仲良くなってから指導した方がうまくいく
# 医薬品製造業だと、ダブルチェックが当たり前すぎてこんな事例は経験したことないな。
# でもモリカケもColaboも、中の人はすっごい勢いで情報開示請求嫌がるしチェックされるの嫌ってますよ。連中「この先やっていける？」ってほど若く見えないし、今までそれでやってきたクズにしか見えないのですが。
# 後で本来のダブルチェックの意味を理解した時にバカにされてたと傷つくかもしれんがとりあえずこれで納得するアホの子にはこのくらいで良いのでは
# なんなら私の仕事全部ダブルチェックして欲しいと願いながら仕事はしてる。
# 流石やな
# どういう工場か分からないけど、複数の工程がある場合、“その工程で問題がない”ことを確認するために検査は必要だよね。でないと、最終的に問題が出た場合に、責任の押し付け合いになりかねない。
# チェックを嫌がるのって、これから先、やっていけなくない？
# こういうのが上司に求められるマネジメントスキルの1つだよなぁ。正論ぶつけるだけでうまく回るとは限らない。相手によってどう返事すれば最適かが異なる。俺には無理だわ…
# 人間誰でもミスをする、というのが根幹だと思うのですが。「流石やな、OK」と言うのは賛成です。
# 誠実とは何か、ごまかしとは何か、嘘つきは泥棒の始まりなのか嘘も方便なのか、人によってこんなにも違うんだな。歩んできた人生が違うから当たり前と言えばそれはそうなんだけど。色々な意見が見れて良い。
# かわいいな
# ちょっとモヤモヤしたが結論としては毒親というのは経済や生産性の視点から見てもクソだという事だ
# 最初はそれで済んでも何れ「そんなに毎回誉めてくれなくてもいいッスよ」ってならない？その後、実際にミスが見つかった時に改めてダブルチェックの必要性を説くのかな。だったら最初からそれやった方がいいのでは。
# 俺の左乳首、俺の右乳首、仲良し合体させて、「ダブチー！」
# すばらしい。ソフトウェアの世界だとLGTM！って元気よく言う。
# そんな漫画みたいなこと言うやついるぅ？
# 私は心理的安全性の方が大事かなと思う。実際ミスが出たとき気を使いそうだし、ミスを隠す可能性が出てくると考えちゃう。
# かつてトラストミーで裏切られたことがあるので…
# マスクCEO、Twitterの無料API終了は「悪質なbotの排除」と説明　有料APIは月100ドル程度に
# マスクのツイートに対し、お金を払うのは悪質botだけだ、というリプライがあるな
# 月100ドル→個人「高いな」／bot「安っす！」でbotだけ残るっぽい
# 月100ドルだと個人開発者だけがいなくなって商業でやってる悪質なBOTだけが残る未来が見える
# botは大して減らねーんだろうなぁという感じがする
# $100/月は個人開発者には流石に高いな...
# 個人開発には辛く、業者には安い価格設定
# 月100ドルはきついわ…個人は10ドルにならんかね…
# blue同様、詐欺･スパム業者が一番の顧客になりそうだね。趣味や勉強のために使ってた人には高いけど、業者なら元が取れるから。
# 悪質なbotはAPI有料化しても減らずスクレイピングに変えるだけじゃないっすかね。
# だったら書き込みだけ有料にしてほしい、、個人開発はスクレイピングに流れるしか無さそう。
# 悪質な中華業者でもスポンサードとして広告費をだすから庶民が怒ってもウェルカムだしチョイスしまくるよーんってAmazonに影響を受けてる? とりま永久凍結やめてくれん？
# 結構高くてワロタ／逆にtogetter 全体に100ドルなら格安だけど、どういう料金体系なんだろ
# 確かに個人開発者より悪質なbotの方が利益も出てそうだし残りそう笑
# これは我々が「悪質」という定義を誤解しているのかもしれない。我々は情報抜いたりウザかったりするbotが悪質だと思うが、マスク視点から見れば無料タダ乗りこそが「悪質」でありカネを払うならそれは良質なのだと。
# これbotを排除したいんじゃなくbotを金にしたいのでは
# 月額100ドルってのがどの範囲なのかだよねえ（例えば、はてなTwitter連携全体で、とかだったら許容範囲だと思うが…
# 「10万個のbotを簡単に起動させることができてしまう」←そんなbotがあったんだろうか。というか、そんなの検出できないんだろうか。
# うん、高いな。青い小鳥を締め出して金払いのいい孔雀ばかり集めている。そろそろアイコンも極彩色の派手な鳥に替えてはどうか。
# 個人開発者終了のお知らせ
# 個人開発とかどうでもいいが。企業botを悪質というのも謎。金払い悪い奴がいい顧客なわけないだろ。そういうとこだぞ日本人。
# 個人開発の地震速報botも有益なのに別SNSに行くらしい。有益なbotの排除は過疎に繋がりそうで困る
# ロシア国民ってこんな感じなのかなぁ
# しょうがないけど金銭感覚…。もし従量制ならそこまでいかないbotも多いかもだけど。botの善悪を区別するのは難しいけど、マネタイズできているbotしか残らないかな。そういえばAPIプロクシあったなあAmazonのとき
# マスクは利益追求って部分においては有能って事になるのかもね。
# 『これでしゅうまいくんは終わりです』ってつぶやきには笑った
# もう、つかわん😤😤😤
# 非営利の有用botも同時に無くなるだろう。既に事例は聞く
# そのうちリツイートやDMも有料化されそう
# とにかく早く有料のクチを増やしたいとみえる
# 悪質なbotがどういうものを指すのかわからないけど、利益が出ないクライアントの存在意義がなくなるのはわりといいことだと思う。ちゃんとアプリ販売料、もしくは広告収入を得て欲しい。
# それにしても普通移行期間は最低一月はとるだろ、なんだよ数日って。
# Web2.0はこうやって終わっていくのかなと思ったり
# あれ、悪くないと思ったらはてブは不満爆発だった
# 本文を読んでないけど悪質なbotの定義がスパム系ならそうかなと思うけどマシュマロみたいなのも凍結されたのを見るにTwitter運営方針か利害かで見てそうなのと月100ドルを平気で払うのってそれこそ商業利用しかないよね
# まあ個人は滅びろってこったよ。就職しろ！
# 個人の趣味や小さな事業をまとめて排除する一方で、パクツイでの荒稼ぎも政府の支援を受けた世論操作も「たった」月100ドル払えばお墨付きをもらえるというわけか。地獄の沙汰も金次第。
# まあ、マスク氏にとっては英語圏での収益改善が優先されることで、日本語圏でのユーザーなんてどうでも良いんだろう、とは思う。
# うーむ……発言回数に応じた従量課金でもした方がマシなんじゃないか？
# 認証マーク有料化の時もそうだったけど、やばいのだけが金払って残りそう。マスクって…
# イーロン・マスクの発言の信ぴょう性は非常に低いので、まともに取り合うだけ無駄だと思う。「何を言っているか」より「何をやったか」に注目したほうが本音が見えてくる。
# 近親婚に対する反論が同性婚反対派のそれと区別つかないのマジウケるな。 ..
# 当事者が声を上げないと話が始まらないことと、賛成が多数かどうかは別の話。あと近親相姦の少なくない割合が家庭内虐待の一つとして行われていることを軽視しすぎ。少なくとも後者は茶化していいことでは全くない。
# そもそも「なら近親婚はどうなんだ？」って関係ない話を持ち出すのが変。それは近親婚を望む人が説明すればいい話で、同性婚推進したい人が近親婚の良い悪いやその理由を説明する必要なくない？
# まあ内心は「社会のバランスが変わってしまう」と思ってる人多そうだよね
# 何故同性婚賛成派だけ「じゃあ○○婚も認めろ！認めないなら偽善者だ！」みたいな踏み絵を踏まされるのか。「近親じゃない異性婚は認めてそれ以外は認めない」だって充分恣意的なのに、そっちは一貫してる扱いなの？
# ドヤ顔で統計的差別を持ち出してくるブクマカ面白すぎるでしょ。男は性犯罪率が高いから女性同士の婚姻以外全部禁止しましょうね〜
# 生物学的な理由付けも、権力勾配的な話もあんま無さそうな『重婚の是非』も併せて議論したいね！
# 内心は「近親婚で家族観や社会が変わる」という人が多いんだろうね。別にそれはそれでいいと思うが、それなら「同性婚で家族観や社会が変わる」も同じ穴の狢として、反発するのではなく受け入れてもらわないとね。
# あくまで保守的な問題なので、リベラルが反差別の視点で近親婚反対を正当化する屁理屈を捏ねても無理だよ。リベラル的にはどちらも可とする以外の結論はない。
# あー、本当だな。ちゃんと考えてなかった。反省“それ、「同じチームにゲイがいたらロッカールームでケツを掘られる！」ってのとどう違うの？”
# “だったら「結婚の平等」なんて持ち出すなよ。結婚の平等を掲げた以上は同性婚以外の婚姻の平等に対する態度を問われるのは当然だろーが”、それはないでしょう。議論においてフォーカスは絞るべき。
# 何かを認めさせるのに他の何かを持ち出すのは得策ではない。下手すると全部まとめて却下されて終わるし。
# 今の日本の情勢なら9割が反対してても同性婚を認めるべきと考えるが、それこそ20年以上前の日本で認めるべきかと問われると自分は疑問だよ。
# インブリード多すぎると故障しやすくなるからなぁ。
# 自分の意見が論理ではなく感情であると認められない人は結構いる。常識や保守的な思想を非合理であると毛嫌いしながら自分が依って立つ部分については無自覚な人も多い。
# そもそも遺伝的多様性の問題は何世代も重ねた場合の話であって、一世代程度では問題はない、という結論が出てた気がするんだけど専門家じゃないのでわからんので、専門家に解説してほしい（丸投げ）
# 詭弁のガイドラインの「一見関係ありそうで関係ない話を始める」に該当するな。「同性間の結婚」と「血縁間の結婚」って切り口が違うでしょう？その違いもわからんの？？
# ながい
# 「同性愛者の9割が同性婚を不要と考えていたとしても同性婚は実現すべき」1割の声があるなら。当事者抜きで制度作るのは反対。婚姻制度自体が云々は正論だけど大仕事になるからまずは本質的平等をという話かと。
# 「なら近親婚はどうなんだ？」whataboutism。その態度では何も解決しないよ。一個一個進めばいい。憲法が具体的な平等のあり方を決めてはいない。公共の福祉含め、社会の総意や合意が決めるところは多々ある
# 感情論で、こっちはいいけどこっちはだめだなって思うならそれはそれでいいのに。その感覚は何に基づいてるかを自問する材料になる。変に感情論を社会倫理に適合させなくてもいいよ（そう、内心ならね）
# 卒業式や入学式でのマスク着用 推奨しないことを検討 政府 | NHK
# 「推奨しない」って意味不明だわ。「強制しない」でいいだろ。入学式とか卒業旅行とか、大学の二次試験や履修登録の時に体調不良になったら目も当てられないな。/ やめろ、って意味にとる人が多いと思う→推奨しない
# 「推奨しない」って「やめとけ」と「是非とまでは言わない」と、解釈が2通りある困った表現な気がする。
# 政府自民党内に、病的に「マスクが嫌い」な人がいるのだろう。卒業式や入学式なんて、マスクを推奨しても経済的損失は一円もないのに。
# "推奨しない" を "推奨という行為をしない。つまり特に指定しない。" と意味で言っているのだろうけど、一般的には "しない方が良い"の意味合いで使うのでだいぶ言葉選びがまずそう。
# 会話はしないだろうけど校歌斉唱やるならマスクはどうしておこうかーとか歌自体を控えるのかとか考えることは多そう
# マスク着用はやめなくて良いから、ありがたーい地元議員とかの来賓挨拶やめてくれないかな。式の時間短縮で感染防止にも繋がると思うんだわ。
# マスクが嫌いとかじゃなくて「一生に一度しかない卒業式なのにマスクをさせられて子どもたちが可哀想」だと思うなあ
# ↓校歌斉唱があるのは気付かなかった…という慧眼なブコメの中にしっかりダジャレを入れてくるのはさすが。
# 卒業式後に入試がある受験生等はよく考えて行動を／“一定の感染対策を講じることを条件に、マスクの着用を推奨しないことを検討““この場合でも、着脱を無理強いすることがないよう求める考え“
# 長男がコロナ禍初の卒業式生だったんだけど、小学生で顔が見えないのはやはり残念だったよね。しょうがないんだけど。高校以上は好きにすればいい。
# こういう文章を書くと先生が喜び自分たちの評価も上がるということを子どもたちは知っているのです。
# みんなこれがガチで小学6年生からの自発的な意見である可能性を踏まえてけなしてるのかな、すげーな / おれもガチの可能性は低いと思ってるけど、これだけの情報量で暴言を吐く度胸はない
# 税金上げてでも防衛費増やすのは賛成なのだけど、子供にはこういう思いを持っていてほしいと思う。「何で中国人を撲滅しないんですか？」みたいな子供はいないので、右翼は子供を利用しようがないな。と思った。
# 気持ち割りぃ…こういうの反吐が出る。自分の言葉と体で文句言え
# ごもっともな疑問だし、自分もこの回答は聞きたい。
# モリカケサクラ学園小学校でやるはずだったんだっけ？
# キッシーに聞くより、プーチンや習近平に聞いた方がいいんじゃないか？
# 子供が次の社会を作っていくのだから政府は堂々と答えるべき。軍事費を国債や増税で充てようと支払うのは次の世代の子ら。岸田が勝手に米国と約束して日本の方向性を変えた説明は未だない。
# と北京日報東部支部が報じた。
# 子供を道具にしたしょうもない手垢のついたパフォーマンス手法だが、一方で質問に対して平易な言葉で納得させられないようでは政治家として困る
# トップコメが気になって調べたけど、小山田圭吾による障がい者いじめの舞台になった学校か。//小学生でも100%納得できる政治を目指したら、それは民主主義じゃなくて全体主義なのかもしれんな。
# 日米防衛同盟で軍事費のgdp比率をアメリカから要請されとるんだろうけど、日本は主権国家なのでさすがに「アメリカにあげろって圧かかって」とは言えないんだよ。察せよ国民。
# さきの戦争中は、子供たちがいちばんに好戦的だったんよねえ。
# よくわかんないけど、マスコミ呼んで記事にさせて擦りまくってからポストに投函？
# なんで教師って、自分がやってることを「クラスが」とか「子どもたちは」とか、主語入れ替えて語りたがるん？
# 子供を政治の道具にするなよ

# %% [markdown]
# ### Python 公式ドキュメント(日本語)

# %%
url = "https://docs.python.org/ja/3/whatsnew/3.11.html"
response = requests.get(url)
soup = BeautifulSoup(response.content, "html.parser")

summary = soup.find("section", attrs={"id": "summary-release-highlights"})
# paragraphs = summary.find_all("p")
for elemment in summary.children:
    print(elemment.get_text())
# Out:
# 概要 -- リリースハイライト¶
#
#
#
# Python 3.11 は Python 3.10 とくらべて 10-60% 高速です。平均的には、標準ベンチマークスイートでは 1.25倍の高速化を計測しました。詳細については Faster CPython を見てください。
#
#
#
# 新たな文法機能:
#
#
#
# PEP 654: Exception Groups and except*
#
#
#
# 新たな組み込み機能:
#
#
#
# PEP 678: Exceptions can be enriched with notes
#
#
#
# 新しい標準ライブラリのモジュール：
#
#
#
# PEP 680: tomllib — TOML のパースを標準ライブラリでサポート
#
#
#
# インタプリタの改善:
#
#
#
# PEP 657: Fine-grained error locations in tracebacks
# New -P command line option and PYTHONSAFEPATH environment
# variable to disable automatically prepending potentially unsafe paths to sys.path
#
#
#
# 新しい型ヒントの機能:
#
#
#
# PEP 646: Variadic generics
# PEP 655: Marking individual TypedDict items as required or not-required
# PEP 673: Self type
# PEP 675: Arbitrary literal string type
# PEP 681: Data class transforms
#
#
#
# 重要な非推奨化、削除と制限：
#
#
#
# PEP 594: たくさんのレガシーの標準ライブラリのモジュールが非推奨になり Python 3.13 で削除されます。
# PEP 624: Py_UNICODE エンコーダー API は削除されました
# PEP 670:
# Macros converted to static inline functions
